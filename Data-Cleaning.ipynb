# %% [markdown]
# ### 🟦 Importing Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ### 🟦 Scrutinizing & Editing Data

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Alireza-Esp/VFCPM/refs/heads/main/Data/data.csv")

# %%
data
# Out:
#        Model year   Make          Model                    Vehicle class  \
# 0            1995  Acura        Integra                       Subcompact
# 1            1995  Acura        Integra                       Subcompact
# 2            1995  Acura   Integra GS-R                       Subcompact
# 3            1995  Acura         Legend                          Compact
# 4            1995  Acura   Legend Coupe                          Compact
# ...           ...    ...            ...                              ...
# 27808        2024  Volvo  V60 CC B5 AWD             Station wagon: Small
# 27809        2024  Volvo  V90 CC B6 AWD          Station wagon: Mid-size
# 27810        2024  Volvo    XC40 B5 AWD     Sport utility vehicle: Small
# 27811        2024  Volvo    XC60 B5 AWD     Sport utility vehicle: Small
# 27812        2024  Volvo    XC90 B6 AWD  Sport utility vehicle: Standard
#
#        Engine size (L)  Cylinders Transmission Fuel type  City (L/100 km)  \
# 0                  1.8          4           A4         X             11.6
# 1                  1.8          4           M5         X             11.0
# 2                  1.8          4           M5         Z             10.8
# 3                  3.2          6           A4         Z             14.2
# 4                  3.2          6           A4         Z             14.6
# ...                ...        ...          ...       ...              ...
# 27808              2.0          4          AS8         Z             10.0
# 27809              2.0          4          AS8         Z             10.7
# 27810              2.0          4          AS8         Z              9.9
# 27811              2.0          4          AS8         Z             10.6
# 27812              2.0          4          AS8         Z             10.9
#
#        Highway (L/100 km)  Combined (L/100 km)  Combined (mpg)  \
# 0                     8.3                 10.1              28
# 1                     8.3                  9.8              29
# 2                     8.3                  9.7              29
# 3                    10.5                 12.5              23
# 4                    11.0                 13.0              22
# ...                   ...                  ...             ...
# 27808                 7.5                  8.9              32
# 27809                 8.1                  9.5              30
# 27810                 7.8                  9.0              31
# 27811                 8.3                  9.6              29
# 27812                 8.6                  9.8              29
#
#        CO2 emissions (g/km)  CO2 rating  Smog rating
# 0                       232         NaN          NaN
# 1                       225         NaN          NaN
# 2                       223         NaN          NaN
# 3                       288         NaN          NaN
# 4                       299         NaN          NaN
# ...                     ...         ...          ...
# 27808                   207         5.0          5.0
# 27809                   223         5.0          7.0
# 27810                   210         5.0          5.0
# 27811                   226         5.0          5.0
# 27812                   230         5.0          7.0
#
# [27813 rows x 15 columns]

# %% [markdown]
# 🔷 About 28000 sample

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27813 entries, 0 to 27812
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model year            27813 non-null  int64
#  1   Make                  27813 non-null  object
#  2   Model                 27813 non-null  object
#  3   Vehicle class         27813 non-null  object
#  4   Engine size (L)       27813 non-null  float64
#  5   Cylinders             27813 non-null  int64
#  6   Transmission          27813 non-null  object
#  7   Fuel type             27813 non-null  object
#  8   City (L/100 km)       27813 non-null  float64
#  9   Highway (L/100 km)    27813 non-null  float64
#  10  Combined (L/100 km)   27813 non-null  float64
#  11  Combined (mpg)        27813 non-null  int64
#  12  CO2 emissions (g/km)  27813 non-null  int64
#  13  CO2 rating            8832 non-null   float64
#  14  Smog rating           7726 non-null   float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# 🔷 The columns "CO2 rating" and "Smog rating" have about 30% NULL values. deleting them...

# %%
data.drop(columns=["CO2 rating", "Smog rating"], inplace=True)

# %%
data
# Out:
#        Model year   Make          Model                    Vehicle class  \
# 0            1995  Acura        Integra                       Subcompact
# 1            1995  Acura        Integra                       Subcompact
# 2            1995  Acura   Integra GS-R                       Subcompact
# 3            1995  Acura         Legend                          Compact
# 4            1995  Acura   Legend Coupe                          Compact
# ...           ...    ...            ...                              ...
# 27808        2024  Volvo  V60 CC B5 AWD             Station wagon: Small
# 27809        2024  Volvo  V90 CC B6 AWD          Station wagon: Mid-size
# 27810        2024  Volvo    XC40 B5 AWD     Sport utility vehicle: Small
# 27811        2024  Volvo    XC60 B5 AWD     Sport utility vehicle: Small
# 27812        2024  Volvo    XC90 B6 AWD  Sport utility vehicle: Standard
#
#        Engine size (L)  Cylinders Transmission Fuel type  City (L/100 km)  \
# 0                  1.8          4           A4         X             11.6
# 1                  1.8          4           M5         X             11.0
# 2                  1.8          4           M5         Z             10.8
# 3                  3.2          6           A4         Z             14.2
# 4                  3.2          6           A4         Z             14.6
# ...                ...        ...          ...       ...              ...
# 27808              2.0          4          AS8         Z             10.0
# 27809              2.0          4          AS8         Z             10.7
# 27810              2.0          4          AS8         Z              9.9
# 27811              2.0          4          AS8         Z             10.6
# 27812              2.0          4          AS8         Z             10.9
#
#        Highway (L/100 km)  Combined (L/100 km)  Combined (mpg)  \
# 0                     8.3                 10.1              28
# 1                     8.3                  9.8              29
# 2                     8.3                  9.7              29
# 3                    10.5                 12.5              23
# 4                    11.0                 13.0              22
# ...                   ...                  ...             ...
# 27808                 7.5                  8.9              32
# 27809                 8.1                  9.5              30
# 27810                 7.8                  9.0              31
# 27811                 8.3                  9.6              29
# 27812                 8.6                  9.8              29
#
#        CO2 emissions (g/km)
# 0                       232
# 1                       225
# 2                       223
# 3                       288
# 4                       299
# ...                     ...
# 27808                   207
# 27809                   223
# 27810                   210
# 27811                   226
# 27812                   230
#
# [27813 rows x 13 columns]

# %%
data["Model year"].value_counts().to_dict()
# Out:
# {2015: 1128,
#  2016: 1106,
#  2009: 1096,
#  2012: 1091,
#  2011: 1085,
#  2018: 1083,
#  2013: 1082,
#  2008: 1079,
#  2014: 1068,
#  2017: 1058,
#  2019: 1056,
#  2007: 1043,
#  2010: 1030,
#  2005: 1019,
#  2022: 976,
#  2020: 975,
#  2021: 970,
#  2006: 968,
#  2004: 898,
#  2023: 840,
#  1995: 839,
#  2003: 820,
#  2024: 768,
#  2002: 740,
#  1996: 698,
#  1999: 688,
#  2001: 679,
#  1997: 658,
#  2000: 638,
#  1998: 634}

# %% [markdown]
# 🔷 The column "Model year" has no problem...

# %%
data["Make"].value_counts().to_dict()
# Out:
# {'Chevrolet': 2615,
#  'Ford': 2255,
#  'BMW': 1721,
#  'GMC': 1677,
#  'Mercedes-Benz': 1466,
#  'Toyota': 1287,
#  'Dodge': 1263,
#  'Porsche': 1090,
#  'Audi': 962,
#  'Volkswagen': 934,
#  'Nissan': 915,
#  'Mazda': 780,
#  'Honda': 685,
#  'Hyundai': 661,
#  'Jeep': 659,
#  'Subaru': 626,
#  'Volvo': 619,
#  'Kia': 575,
#  'Lexus': 537,
#  'Cadillac': 511,
#  'Chrysler': 504,
#  'MINI': 449,
#  'Jaguar': 433,
#  'Pontiac': 390,
#  'Buick': 339,
#  'Mitsubishi': 335,
#  'Acura': 319,
#  'Infiniti': 313,
#  'Land Rover': 265,
#  'Suzuki': 260,
#  'Lincoln': 252,
#  'Saab': 252,
#  'Saturn': 216,
#  'Bentley': 171,
#  'Ram': 165,
#  'Maserati': 161,
#  'Rolls-Royce': 133,
#  'Lamborghini': 123,
#  'Aston Martin': 118,
#  'Ferrari': 94,
#  'Plymouth': 88,
#  'FIAT': 86,
#  'Oldsmobile': 79,
#  'Genesis': 60,
#  'Alfa Romeo': 58,
#  'Mercury': 57,
#  'Isuzu': 47,
#  'Scion': 44,
#  'Eagle': 41,
#  'Daewoo': 41,
#  'smart': 22,
#  'Hummer': 21,
#  'Geo': 19,
#  'Bugatti': 16,
#  'SRT': 4}

# %% [markdown]
# 🔷 SRT is subcategory of Dodge.

# %%
data.loc[data["Make"] == "SRT", "Make"] = "Dodge"

# %%
data["Model"].value_counts().to_dict()
# Out:
# {'Mustang': 136,
#  'F-150': 107,
#  'Jetta': 107,
#  'F-150 4X4': 98,
#  'Corolla': 88,
#  'Ranger': 88,
#  'Silverado': 83,
#  'Sierra': 83,
#  'Camaro': 81,
#  'Sierra 4WD': 78,
#  'Silverado 4WD': 78,
#  'F-150 FFV': 76,
#  'Sentra': 74,
#  'Camry': 73,
#  'Ram 1500': 73,
#  'Accord': 72,
#  'Tacoma': 71,
#  'K1500 Sierra 4X4': 71,
#  'A4 quattro': 71,
#  'Altima': 70,
#  'C1500 Sierra': 70,
#  'Elantra': 69,
#  'Dakota': 69,
#  'Passat': 68,
#  'F-150 FFV 4X4': 66,
#  'Malibu': 62,
#  'Canyon': 62,
#  'Colorado': 62,
#  'Dakota 4X4': 62,
#  'Frontier': 61,
#  'Sonata': 59,
#  'Corvette': 57,
#  'Accent': 56,
#  'Legacy AWD': 56,
#  'Ranger 4X4': 50,
#  'Compass': 50,
#  'Grand Caravan': 50,
#  'A6 quattro': 50,
#  'Escape': 49,
#  'Tacoma 4WD': 49,
#  'Civic': 48,
#  'Versa': 48,
#  'Lancer': 47,
#  'Impala': 47,
#  'Rio': 46,
#  'Forester AWD': 46,
#  'CTS': 46,
#  'Grand Cherokee 4X4': 46,
#  'Impreza AWD': 46,
#  'Tundra': 46,
#  'Mazda6': 45,
#  'Forte': 45,
#  'Fusion': 43,
#  'Boxster': 43,
#  'Sunfire': 43,
#  '911 Carrera': 43,
#  'Cavalier': 42,
#  'Tacoma 4X4': 42,
#  'Golf': 42,
#  'Patriot': 42,
#  'A4': 41,
#  'Maxima': 41,
#  'Sportage': 40,
#  'Equinox AWD': 40,
#  'Soul': 40,
#  'Edge AWD': 39,
#  'Passat Wagon': 39,
#  'Cooper Convertible': 39,
#  'Tucson': 39,
#  'Challenger': 39,
#  'Eclipse': 39,
#  'Cherokee': 39,
#  'Ram 1500 4X4': 38,
#  'New Beetle': 38,
#  'Regal': 38,
#  'Focus': 37,
#  'TJ 4X4': 37,
#  'Cooper S Convertible': 37,
#  'Canyon 4WD': 37,
#  'C1500 Silverado': 37,
#  'Colorado 4WD': 37,
#  'Equinox': 37,
#  'Sebring': 37,
#  'Tiburon': 37,
#  'Santa Fe': 37,
#  'Mazda3': 36,
#  'K1500 Silverado 4X4': 36,
#  'Fit': 36,
#  'MX-5': 36,
#  'E150 Van': 35,
#  'GTI': 35,
#  'Outback AWD': 34,
#  'Boxster S': 34,
#  'Grand Caravan FFV': 34,
#  'Sierra FFV': 34,
#  'Silverado FFV': 34,
#  'Corolla Matrix': 33,
#  'Yukon 4WD': 33,
#  'Terrain AWD': 33,
#  'Yukon XL': 33,
#  'Compass 4X4': 33,
#  'Mustang Convertible': 33,
#  '911 Turbo': 33,
#  '626': 32,
#  'Tahoe 4WD': 32,
#  '911 Carrera 4S': 32,
#  'Caravan': 32,
#  '911 Carrera 4': 32,
#  'Eclipse Spyder': 32,
#  'Charger': 32,
#  '4Runner 4X4': 32,
#  'Grand Am': 31,
#  'Suburban': 31,
#  'Yukon XL 4WD': 31,
#  'Explorer 4X4': 31,
#  'Sienna': 30,
#  'E150 Club Wagon': 30,
#  '911 Carrera S Cabriolet': 30,
#  '911 Carrera S': 30,
#  'Charger FFV': 30,
#  'Celica': 30,
#  'Tahoe': 30,
#  'Terrain': 30,
#  'Protege': 30,
#  'Focus FFV': 30,
#  'Yukon': 30,
#  'B4000 4X4': 30,
#  'Forte 5': 29,
#  'CR-V': 29,
#  'Odyssey': 29,
#  'Civic Sedan': 29,
#  '911 Carrera Cabriolet': 29,
#  'Avenger': 29,
#  'Sebring Convertible': 29,
#  'Suburban 4WD': 29,
#  'S10': 28,
#  'Firebird': 28,
#  'Neon': 28,
#  'Magentis': 28,
#  'Charger (MDS)': 28,
#  'Impreza Wagon AWD': 28,
#  '911 Carrera 4S Cabriolet': 28,
#  'Expedition 4X4': 28,
#  'HHR': 28,
#  'Forte Koup': 28,
#  'Escape AWD': 28,
#  'Camaro SS': 28,
#  '911 Carrera 4 Cabriolet': 28,
#  'Tundra 4WD': 27,
#  'Sonic 5': 27,
#  'B3000': 27,
#  'Sonic': 27,
#  'C1500': 27,
#  'TSX': 27,
#  'Ram 2500 Van': 27,
#  'K1500 4X4': 27,
#  'Cruze': 26,
#  'Avalon': 26,
#  'Civic Hatchback': 26,
#  'Taurus': 26,
#  'Outlander 4WD': 26,
#  'TT Coupe quattro': 26,
#  'Cherokee 4X4': 26,
#  'Ram 1500 Van': 26,
#  '300': 26,
#  'Pathfinder 4X4': 26,
#  'Grand Prix': 26,
#  'NSX': 26,
#  'Cayenne': 26,
#  'A4 Avant quattro': 26,
#  'RAV4': 26,
#  'Acadia AWD': 25,
#  'Colorado Crew Cab': 25,
#  'Yaris': 25,
#  'Continental GT': 25,
#  'A8L': 25,
#  'B4000': 25,
#  'Canyon Crew Cab': 25,
#  'S4': 25,
#  'C2500 Sierra': 24,
#  'Beetle': 24,
#  'Accord Coupe': 24,
#  'ATS': 24,
#  'Silverado 4WD FFV': 24,
#  'Camaro ZL1': 24,
#  'Sierra 4WD FFV': 24,
#  'Tribute': 24,
#  'Acadia': 24,
#  'Monte Carlo': 24,
#  'Cayman': 24,
#  'Explorer': 24,
#  'Mazda3 4-Door': 24,
#  'Vue': 24,
#  'Intrepid': 24,
#  'Frontier 4WD': 24,
#  'Sorento AWD': 23,
#  'Edge': 23,
#  'SRX AWD': 23,
#  'TT Roadster quattro': 23,
#  'Mazda3 5-Door': 23,
#  '911 Turbo Cabriolet': 23,
#  'Camry Solara': 23,
#  'Explorer AWD': 23,
#  'Elantra GT': 23,
#  'Patriot 4X4': 23,
#  'Pilot AWD': 23,
#  'Golf GTI': 22,
#  'MX-5 Miata': 22,
#  'New Beetle Convertible': 22,
#  'Cooper': 22,
#  'Cayman S': 22,
#  'Tracker Convertible 4X4': 22,
#  'Voyager': 22,
#  'Liberty 4X4': 22,
#  'Lancer Sportback': 22,
#  '911 Targa 4S': 22,
#  'Z3': 22,
#  'Prius': 22,
#  'RVR 4WD': 22,
#  'RVR': 22,
#  'A3': 22,
#  '370Z Roadster': 22,
#  'Optima': 22,
#  'M3': 22,
#  'BRZ': 22,
#  'E250 Van': 22,
#  'G6': 21,
#  'Murano AWD': 21,
#  'B2300': 21,
#  'G15/G25 Chevy Van': 21,
#  'PT Cruiser': 21,
#  'Grand Voyager': 21,
#  'Canyon 4X4': 21,
#  'Sorento': 21,
#  'SRX': 21,
#  'John Cooper Works Convertible': 21,
#  'Cooper S Countryman ALL4': 21,
#  'Tiguan': 21,
#  'Challenger (MDS)': 21,
#  'Mirage': 21,
#  'K1500 Yukon 4X4': 21,
#  'Colorado 4X4': 21,
#  'Phantom': 21,
#  'RX 350 AWD': 21,
#  'Wrangler 4X4': 21,
#  'Altima Coupe': 21,
#  'G15/G25 Savana Cargo': 21,
#  'Highlander': 21,
#  'Q7': 21,
#  'Taurus FFV': 21,
#  'Quest': 20,
#  'Mystique': 20,
#  'Genesis Coupe': 20,
#  '370Z': 20,
#  'V8 Vantage': 20,
#  'R8': 20,
#  'Vibe': 20,
#  'CTS AWD': 20,
#  'Sportage AWD': 20,
#  'Sequoia 4WD': 20,
#  'Touareg': 20,
#  'Contour': 20,
#  'S15 Sonoma': 20,
#  'R8 Spyder': 20,
#  'Mazda5': 20,
#  'X-TYPE': 20,
#  'Formula': 20,
#  'X5': 20,
#  '320i': 20,
#  'Cayenne S': 20,
#  'HHR Panel': 20,
#  'CR-V AWD': 20,
#  'Spark': 20,
#  'M6 Cabriolet': 20,
#  'Cooper S Clubman': 20,
#  'M5': 19,
#  'WRX AWD': 19,
#  'LS': 19,
#  'Durango 4X4': 19,
#  'A8': 19,
#  'Mazda3 5-Door (SIL)': 19,
#  'Cooper 3 Door': 19,
#  'Santa Fe AWD': 19,
#  'Savana 2500 Passenger': 19,
#  'Express 2500 Passenger': 19,
#  'G80 AWD': 19,
#  'Sedona': 19,
#  'Cooper S 5 Door': 19,
#  'Cooper S 3 Door': 19,
#  'Cooper 5 Door': 19,
#  'Civic Coupe': 19,
#  'Jetta TDI Diesel': 19,
#  'Accord Sedan': 19,
#  'Cobalt': 19,
#  '911 Targa 4': 19,
#  'Caliber': 19,
#  'Cayenne Turbo': 19,
#  'Crosstrek AWD': 19,
#  'F-250': 19,
#  'Rogue': 19,
#  'Rogue AWD': 19,
#  'Rondo': 19,
#  '4Runner 4WD': 19,
#  'ES 350': 18,
#  'RAV4 4X4': 18,
#  'Fiesta': 18,
#  'Impala FFV': 18,
#  'C2500': 18,
#  'Frontier V6 4X4': 18,
#  'MKZ AWD': 18,
#  'Metro': 18,
#  'Challenger SRT Hellcat': 18,
#  'Concorde': 18,
#  'A5 quattro': 18,
#  'Town & Country': 18,
#  'Cooper Clubman': 18,
#  'Trax': 18,
#  'Ram 2500 Wagon': 18,
#  'Firefly': 18,
#  '300 AWD': 18,
#  'Journey FFV': 18,
#  'Grand Marquis': 18,
#  '300 FFV': 18,
#  '530i': 18,
#  '525i': 17,
#  'Express 3500 Passenger': 17,
#  'C1500 Yukon': 17,
#  'K1500 Tahoe 4X4': 17,
#  'SLK 350': 17,
#  'John Cooper Works Countryman ALL4': 17,
#  'CX-5': 17,
#  'Alero': 17,
#  'IS 250': 17,
#  'Cooper S': 17,
#  'Sienna AWD': 17,
#  'Tercel': 17,
#  'Durango AWD': 17,
#  'Tucson AWD': 17,
#  'Enclave AWD': 17,
#  'Cherokee 4X4 Active Drive I': 17,
#  'Escalade AWD': 17,
#  'Flying Spur': 17,
#  'Golf TDI Diesel': 17,
#  'Outlander': 17,
#  'CSX': 17,
#  'Charger AWD': 17,
#  'Savana 3500 Passenger': 17,
#  'Town Car': 17,
#  'Vue AWD': 16,
#  'Renegade 4X4': 16,
#  'Suburban FFV': 16,
#  'Tiguan 4MOTION': 16,
#  'Spectra': 16,
#  '300 AWD FFV': 16,
#  'Escape 4X4': 16,
#  '528i': 16,
#  'Charger AWD FFV': 16,
#  '9-5 Turbo': 16,
#  'Range Rover 4X4': 16,
#  'HR-V AWD': 16,
#  'Fusion AWD': 16,
#  'Cabrio': 16,
#  'Focus Wagon': 16,
#  '9-3 SportCombi Turbo': 16,
#  '9-3 Convertible Turbo': 16,
#  'New Beetle TDI Diesel': 16,
#  'Cougar': 16,
#  'Grand Prix #': 16,
#  '1500 FFV': 16,
#  'Crown Victoria': 16,
#  'TL': 16,
#  'E150 Van FFV': 16,
#  'Z4 Roadster': 16,
#  'Frontier V6': 16,
#  'SL #': 16,
#  'Golf R': 16,
#  'Civic Si': 16,
#  'Grand Cherokee 4X4 FFV': 16,
#  'Cherokee 4X4 Active Drive II': 16,
#  'Wrangler JL Unlimited 4X4': 16,
#  'Yukon XL FFV': 16,
#  '540i': 16,
#  'Aveo': 16,
#  'Verano': 16,
#  'Jetta GLI': 16,
#  'SL': 16,
#  'RX-8': 16,
#  'Tahoe FFV': 16,
#  '328i': 16,
#  'Tribute 4X4': 16,
#  '911 GT3': 16,
#  'S10 4X4': 16,
#  'Traverse AWD': 16,
#  'Ion': 16,
#  'Lanos': 16,
#  'Yukon FFV': 16,
#  'Ram 1500 Wagon': 16,
#  'Escalade 4WD': 15,
#  'Enclave': 15,
#  'C1500 Suburban': 15,
#  'S5': 15,
#  'M4 Coupe': 15,
#  'C70 Convertible Turbo': 15,
#  'Eos': 15,
#  'C1500 Tahoe': 15,
#  'CX-5 4WD': 15,
#  'Q50 AWD': 15,
#  'Wrangler JL 4X4': 15,
#  'Ridgeline AWD': 15,
#  'HR-V': 15,
#  'Integra': 15,
#  'Titan': 15,
#  'Ghost': 15,
#  'Traverse': 15,
#  'IS 300': 15,
#  'MKS AWD': 15,
#  'Pacifica': 15,
#  'Venza': 15,
#  'Q5': 15,
#  'STS': 15,
#  'Veloster': 15,
#  'GS 300': 15,
#  'Corvette Z06': 15,
#  'IS 350 AWD': 15,
#  'Trooper 4X4': 14,
#  'SW Wagon #': 14,
#  'Transit Connect Wagon LWB FFV': 14,
#  'GT-R': 14,
#  'Pathfinder 4WD': 14,
#  '323i': 14,
#  'SL 550': 14,
#  'Passat 4MOTION': 14,
#  '911 Turbo S': 14,
#  'Journey': 14,
#  'Kona AWD': 14,
#  'E150 Wagon FFV': 14,
#  'X6 M': 14,
#  'Armada 4WD': 14,
#  'RSX': 14,
#  'Gallardo Spyder': 14,
#  'Impreza 5-Door AWD': 14,
#  'Juke': 14,
#  'Jetta Wagon': 14,
#  'LaCrosse': 14,
#  'Swift+': 14,
#  'GX 460': 14,
#  'Jetta TDI (modified)': 14,
#  'Mazda3 4-Door (SIL)': 14,
#  'Sonata Hybrid': 14,
#  'Vanden Plas': 14,
#  'Rodeo 4X4': 14,
#  'FJ Cruiser 4WD': 14,
#  'Sebring FFV': 14,
#  'Avalanche': 14,
#  '325Ci Convertible': 14,
#  '325Ci': 14,
#  'S6': 14,
#  '328i Coupe': 14,
#  'Escort': 14,
#  'Grand Vitara 4X4': 14,
#  'Grand Caravan AWD': 14,
#  'MKX AWD': 14,
#  'Swift': 14,
#  'Sportage 4X4': 14,
#  'Blazer': 14,
#  '328i Cabriolet': 14,
#  'A3 quattro': 14,
#  'Ram 1500 FFV': 14,
#  'Stratus': 14,
#  'Transit Connect Van FFV': 14,
#  '335i Coupe': 14,
#  'Continental GT Convertible': 14,
#  '325i': 14,
#  '330Ci': 14,
#  'Phantom EWB': 14,
#  '200 FFV': 14,
#  'Veloster Turbo': 14,
#  'Taurus FFV AWD': 14,
#  'RAV4 AWD': 14,
#  'Explorer FFV AWD': 14,
#  'Windstar Wagon': 14,
#  'Explorer Sport Trac 4X4': 14,
#  'Lancer Evolution': 14,
#  'Pilot': 14,
#  '335i Cabriolet': 14,
#  '330i': 14,
#  '330Ci Convertible': 14,
#  'Silverado 4X4': 13,
#  'Galant': 13,
#  'RX 450h AWD': 13,
#  'Element': 13,
#  'CX-9 4WD': 13,
#  'Civic Hybrid': 13,
#  'MKT AWD': 13,
#  'Camry Hybrid LE': 13,
#  'Z4 sDrive35i': 13,
#  'Lucerne': 13,
#  'Taurus AWD': 13,
#  'ILX': 13,
#  'Escape Hybrid': 13,
#  'LX 570': 13,
#  'ATS AWD': 13,
#  'Tundra 4X4': 13,
#  'Dart': 13,
#  'Grand Vitara': 13,
#  'Transit Connect Van': 13,
#  'S-TYPE': 13,
#  'Highlander AWD': 13,
#  'MKZ': 13,
#  'X1 xDrive28i': 13,
#  'Silverado 4WD Mud Terrain Tire': 13,
#  'GS 350 AWD': 13,
#  'S60 T5 Turbo': 13,
#  'F-TYPE Convertible': 13,
#  'Venza AWD': 13,
#  'Cooper Countryman': 13,
#  'Navigator 4X4': 13,
#  'Sierra 4X4': 13,
#  'Flex AWD': 13,
#  'Sierra 4WD Mud Terrain Tire': 13,
#  'SL 600': 13,
#  'Qashqai': 13,
#  'Colorado ZR2 4WD': 13,
#  'S 600': 13,
#  'Taurus #': 13,
#  'Century': 13,
#  'XJR #': 13,
#  'A6': 13,
#  'XT5 AWD': 13,
#  'John Cooper Works 3 Door': 13,
#  'Envision AWD': 13,
#  'Tracker Van 4X4': 13,
#  '1500 4X4 eTorque': 12,
#  'SX4 Sedan Sport': 12,
#  'Bonneville': 12,
#  'Town & Country FFV': 12,
#  'Explorer Sport Trac': 12,
#  'ES 300h': 12,
#  'Taurus Wagon': 12,
#  'Beetle Convertible': 12,
#  'GranTurismo': 12,
#  'Nitro 4X4': 12,
#  '330xi': 12,
#  '325xi': 12,
#  'Echo': 12,
#  'G5': 12,
#  '1500 eTorque': 12,
#  'S4 Cabriolet': 12,
#  'G20': 12,
#  'MX-6': 12,
#  'Cayenne GTS': 12,
#  'Escalade ESV AWD': 12,
#  'Yukon Denali AWD': 12,
#  'Passat 4MOTION Wagon': 12,
#  '911 Turbo S Cabriolet': 12,
#  'Nautilus AWD': 12,
#  'G15/G25 Savana Passenger': 12,
#  'Q70 AWD': 12,
#  'Windstar Van': 12,
#  'Gallardo': 12,
#  'XJ8': 12,
#  'Sierra 4WD AT4': 12,
#  'TrailBlazer': 12,
#  'TrailBlazer 4X4': 12,
#  'G70 AWD': 12,
#  'Prelude': 12,
#  'G 550': 12,
#  'Envoy 4X4': 12,
#  'John Cooper Works': 12,
#  'CR-Z': 12,
#  'Savana Cargo': 12,
#  'Sentra/200SX': 12,
#  'M4 Cabriolet': 12,
#  '1500 Classic': 12,
#  'CTS-V': 12,
#  'Express Cargo': 12,
#  'LaCrosse AWD': 12,
#  'Avenger FFV': 12,
#  '1500 Classic 4X4': 12,
#  'M6 Coupe': 12,
#  'Renegade': 12,
#  '612 Scaglietti': 12,
#  'Blazer 4X4': 12,
#  'Xterra 4WD': 12,
#  '335i': 12,
#  'Continental AWD': 12,
#  'F-TYPE Coupe': 12,
#  'Sorento 4X4': 12,
#  '911 Carrera GTS': 12,
#  'Esteem': 12,
#  'Escape FFV': 12,
#  '135i Coupe': 12,
#  '135i Cabriolet': 12,
#  'Bronco 4WD': 12,
#  '128i Coupe': 12,
#  'Colt': 12,
#  '128i Cabriolet': 12,
#  'Caravan FFV': 12,
#  'tC': 12,
#  'Panamera 4S': 12,
#  'Sonoma': 12,
#  'Highlander Hybrid AWD': 12,
#  '911 Carrera 4 GTS': 12,
#  'Impreza 4-Door AWD': 12,
#  '9-3 Turbo': 12,
#  'G15/G25 Chevy Express': 12,
#  'Jimmy 4X4': 12,
#  '911 Carrera 4 GTS Cabriolet': 12,
#  'Explorer FFV': 12,
#  'X5 M': 12,
#  '911 Carrera GTS Cabriolet': 12,
#  'Wrangler Unlimited 4X4': 11,
#  'M3 Sedan': 11,
#  'STS AWD': 11,
#  'C70 Turbo': 11,
#  'G37 Coupe': 11,
#  '550i': 11,
#  'Bronco Badlands 4WD': 11,
#  'Journey AWD': 11,
#  'Ghost EWB': 11,
#  'GS 450h': 11,
#  'Allure': 11,
#  '9-5 Wagon Turbo': 11,
#  'CT6 AWD': 11,
#  'CX-9': 11,
#  '328i xDrive Touring': 11,
#  'M3 Coupe': 11,
#  'DB9': 11,
#  'C 300 4MATIC': 11,
#  'X6 xDrive35i': 11,
#  'Quattroporte': 11,
#  'TL AWD': 11,
#  'M6 Gran Coupe': 11,
#  'Blazer AWD': 11,
#  '9-7X AWD': 11,
#  'Murano': 11,
#  'K1500 Suburban 4X4': 11,
#  'Bronco Sasquatch 4WD': 11,
#  'QX80 4WD': 11,
#  'Titan 4WD': 11,
#  '760Li': 11,
#  'F-150 (LT Tire Pkg)': 11,
#  'CC': 11,
#  'F-150 Raptor 4X4': 11,
#  'LeSabre': 11,
#  'Park Avenue': 11,
#  'Park Avenue #': 11,
#  'SL 500': 11,
#  'DeVille': 11,
#  'Accord Hybrid': 11,
#  'Envoy': 11,
#  'Panamera': 11,
#  'Fusion Hybrid': 11,
#  'Continental GTC': 11,
#  'Millenia': 11,
#  'E 320': 11,
#  'Cooper Countryman ALL4': 11,
#  'Panamera 4': 11,
#  'CL 600': 11,
#  'Flex': 11,
#  'X3': 10,
#  'Golf Wagon TDI (modified)': 10,
#  'Golf Wagon': 10,
#  'S8': 10,
#  'XC60 T6 AWD': 10,
#  'V8 Vantage S': 10,
#  'R8 Coupe': 10,
#  'XKR #': 10,
#  'Mulsanne': 10,
#  '1500': 10,
#  'Yukon XL 4WD FFV': 10,
#  'S2000': 10,
#  'XKR Convertible #': 10,
#  'S4 Avant': 10,
#  'Cherokee 4X4 Active Drive Lock': 10,
#  'Expedition 4X4 FFV': 10,
#  'Golf TDI (modified)': 10,
#  'Yukon 4WD FFV': 10,
#  'Cooper S Clubman ALL4': 10,
#  'Magnum': 10,
#  'John Cooper Works Clubman ALL4': 10,
#  'Truck': 10,
#  'X6 xDrive50i': 10,
#  'Panamera Turbo': 10,
#  'Z4 sDrive30i': 10,
#  'Aerio': 10,
#  'Transit Connect Wagon LWB': 10,
#  'F-150 FFV (Payload Pkg)': 10,
#  '3.2TL': 10,
#  'CTS Sport Wagon': 10,
#  'CTS Sport Wagon AWD': 10,
#  'S5 Cabriolet': 10,
#  '1.7EL': 10,
#  'A4 Cabriolet': 10,
#  'SW Wagon': 10,
#  '328i xDrive Coupe': 10,
#  'C1500 Yukon FFV': 10,
#  'Gladiator 4X4': 10,
#  'Optima Hybrid': 10,
#  '335i xDrive Coupe': 10,
#  'MKZ Hybrid': 10,
#  'C1500 Tahoe FFV': 10,
#  'M3 Cabriolet': 10,
#  'SC #': 10,
#  'X5 xDrive50i': 10,
#  'Z4 sDrive28i': 10,
#  'F-150 FFV (LT Tire Pkg)': 10,
#  'SC': 10,
#  'Bentayga': 10,
#  'S15 Sonoma 4X4': 10,
#  'allroad quattro': 10,
#  'S60': 10,
#  'F-150 4X4 FFV': 10,
#  'C1500 Yukon XL FFV': 10,
#  'GS 430': 10,
#  'RAV4 4WD': 10,
#  'Crossfire': 10,
#  'Legacy Wagon AWD': 10,
#  'Q45': 10,
#  'Achieva': 10,
#  'Aurora': 10,
#  'xB': 10,
#  'E 300 4MATIC': 10,
#  'Escort Wagon': 10,
#  'Cruze Eco': 10,
#  'G90 AWD': 10,
#  'F-150 FFV 4X4 (LT Tire Pkg)': 10,
#  'M3 Convertible': 10,
#  'Probe': 10,
#  'F-150 4X4 (LT Tire Pkg)': 10,
#  'Thunderbird': 10,
#  'Phantom Drophead Coupe': 10,
#  'Paseo': 10,
#  'Durango AWD FFV': 10,
#  'C1500 Suburban FFV': 10,
#  'Xterra V6 4X4': 10,
#  'Sierra Denali AWD': 10,
#  'MKC AWD': 10,
#  'Taurus Wagon #': 10,
#  'RC 350 AWD': 10,
#  'LS 460': 10,
#  'B 200 Turbo': 10,
#  'A6 Avant quattro': 10,
#  'Corolla Hatchback': 10,
#  'Legacy 2.5i': 10,
#  '650i Cabriolet': 10,
#  '1500 4X4 FFV': 10,
#  'Aveo 5': 10,
#  'CT4': 10,
#  'Q60 AWD': 10,
#  'IS 350': 10,
#  'IS 250 AWD': 10,
#  'MPV': 10,
#  'Dakota FFV': 10,
#  'T-150 Wagon FFV': 10,
#  '500L': 10,
#  'Carrera 4S Cabriolet': 10,
#  'XK8': 10,
#  'E 550 4MATIC': 10,
#  'H3 4X4': 10,
#  '1500 4X4': 10,
#  'XK8 Convertible': 10,
#  'Breeze': 10,
#  '318ti': 10,
#  'Carrera 4 Cabriolet': 10,
#  'Silverado 4X4 FFV': 10,
#  '318i Convertible': 10,
#  'RC F': 10,
#  'Regal AWD': 10,
#  'S40 2.4i': 10,
#  '4Runner 4WD (Part-Time 4WD)': 10,
#  'Micra': 10,
#  'Bronco Black Diamond 4WD': 10,
#  'CT4 AWD': 10,
#  'Astro Cargo': 10,
#  'Sierra 4X4 FFV': 10,
#  'Safari Cargo': 10,
#  'Seville': 10,
#  'Grand Caravan FFV C/V': 10,
#  'Astro Passenger': 10,
#  'CT5': 10,
#  'Town & Country AWD': 10,
#  'CT5 AWD': 10,
#  'QX60 AWD': 10,
#  'Esteem Wagon': 10,
#  'Tahoe 4WD FFV': 10,
#  'Safari Passenger': 10,
#  'QX50 AWD': 10,
#  'Suburban 4WD FFV': 10,
#  '500 Cabrio': 10,
#  '500 Hatchback': 10,
#  'LS 460 L AWD': 9,
#  'Fiesta SFE': 9,
#  'Envoy XL 4X4': 9,
#  'Phantom Coupe': 9,
#  'GS 350': 9,
#  'XT6 AWD': 9,
#  'Savana 1500 Cargo': 9,
#  'CX-3': 9,
#  'LS 460 AWD': 9,
#  'Charger AWD (MDS)': 9,
#  'Express 1500 Cargo': 9,
#  'TrailBlazer EXT 4X4': 9,
#  'PT Turbo #': 9,
#  'MX-5 (SIL)': 9,
#  'Hombre': 9,
#  'Macan S': 9,
#  'Mustang #': 9,
#  'Bonneville #': 9,
#  'E 350 4MATIC': 9,
#  'RAV4 Hybrid AWD': 9,
#  'Pacifica AWD': 9,
#  'Civic Coupe Si': 9,
#  '350Z Roadster': 9,
#  'B 200': 9,
#  'S60 T5': 9,
#  'CX-30 4WD': 9,
#  '750i xDrive': 9,
#  'A5 Cabriolet quattro': 9,
#  'XLR': 9,
#  'Sequoia 4X4': 9,
#  'fortwo cabriolet': 9,
#  'Mustang (Performance Pkg)': 9,
#  'SC 430': 9,
#  'MDX SH-AWD': 9,
#  'S60 T6 AWD': 9,
#  'Truck 4X4': 9,
#  'TLX SH-AWD': 9,
#  'Genesis': 9,
#  'FX35 AWD': 9,
#  'LX 470': 9,
#  'Cooper Clubman ALL4': 9,
#  'Prius c': 9,
#  'Encore AWD': 9,
#  'F-250 4X4': 9,
#  'Encore': 9,
#  '350Z': 9,
#  '3.5RL': 9,
#  'Atlas Cross Sport 4MOTION': 9,
#  'G1500/G2500 Chevy Express': 9,
#  'Sentra SR': 9,
#  'F-150 (Payload Pkg)': 9,
#  'Insight': 9,
#  'Venture': 9,
#  'F-150 4X4 (Payload Pkg)': 9,
#  'Legacy AWD Wagon': 9,
#  'G1500/G2500 Savana Passenger': 9,
#  'Discovery 4X4': 9,
#  'ES 300': 9,
#  'X4 M40i': 9,
#  'Grand Cherokee 4X4 (MDS)': 9,
#  'IS 300 AWD': 9,
#  'X3 xDrive30i': 9,
#  'NV200 Cargo Van': 9,
#  'Aventador Coupe': 9,
#  'Lumina': 9,
#  'TT Roadster': 9,
#  'RC 300 AWD': 9,
#  'Camry Solara Convertible': 9,
#  'X3 xDrive28i': 9,
#  'S4 quattro': 9,
#  'LS 600h L': 8,
#  'Navigator 4X4 FFV': 8,
#  'XT5': 8,
#  'GranTurismo Convertible': 8,
#  'Ram 1500 FFV 4X4': 8,
#  'Ghibli': 8,
#  'Panamera 4S Executive': 8,
#  'Mazda2': 8,
#  'Sierra XFE': 8,
#  'E 550 Coupe': 8,
#  'E 320 Wagon': 8,
#  'Corsair AWD': 8,
#  'Xterra 4X4': 8,
#  'G6 Convertible': 8,
#  'John Cooper Works Clubman': 8,
#  'AMG GLC 43 4MATIC Coupe': 8,
#  'V60 T6 AWD': 8,
#  '9-3 Sport Turbo': 8,
#  'Sorento 4WD': 8,
#  'Durango 4X4 FFV': 8,
#  'G37 Convertible': 8,
#  'M240i xDrive Coupe': 8,
#  'Skylark': 8,
#  '1.6EL': 8,
#  'M240i Coupe': 8,
#  'Sportage 4WD': 8,
#  'G15 Express Passenger': 8,
#  'Cube': 8,
#  'X5 xDrive35i': 8,
#  'Envoy XL': 8,
#  'Seltos AWD': 8,
#  'ProMaster City': 8,
#  'CTS-V Sport Wagon': 8,
#  'Grand Cherokee L 4X4': 8,
#  'Jetta Wagon TDI Diesel': 8,
#  'Tahoe 4X4 FFV': 8,
#  '86': 8,
#  'Elantra Wagon': 8,
#  'Rainier AWD': 8,
#  '240SX': 8,
#  'TrailBlazer EXT': 8,
#  'X5 xDrive35d': 8,
#  'Niro': 8,
#  'Cayman GTS': 8,
#  '750Li xDrive': 8,
#  'G15 Savana Passenger': 8,
#  'Expedition': 8,
#  'Silverado XFE': 8,
#  'K900': 8,
#  'Regal #': 8,
#  '124 Spider': 8,
#  'G35 Coupe': 8,
#  'Boxster GTS': 8,
#  'F430 Coupe': 8,
#  'E350 Wagon FFV': 8,
#  'F430 Spider': 8,
#  'Wraith': 8,
#  '599 GTB Fiorano': 8,
#  '200 Convertible FFV': 8,
#  'Optra': 8,
#  '200 Convertible': 8,
#  '650i Coupe': 8,
#  'Renegade FFV': 8,
#  'Aerio Fastback': 8,
#  'Niro FE': 8,
#  '335i xDrive': 8,
#  'Ram 2500': 8,
#  'SLK 250': 8,
#  'Sonoma 4X4': 8,
#  'T100 4X4': 8,
#  'T100': 8,
#  'Summit Wagon': 8,
#  'Outback Sport AWD': 8,
#  'Carrera 2 Coupe': 8,
#  'S10 FFV': 8,
#  'Trailblazer': 8,
#  'Carrera 4S Coupe': 8,
#  '9-3 Sport Sedan Turbo': 8,
#  'fortwo coupe': 8,
#  'SX4 Sedan': 8,
#  'Eurovan': 8,
#  'C 350 4MATIC': 8,
#  'S10 Blazer 4X4': 8,
#  'S10 Blazer': 8,
#  '718 Boxster S': 8,
#  'Focus Wagon #': 8,
#  'Crossfire Roadster': 8,
#  'Sonoma FFV': 8,
#  'PT Cruiser Convertible': 8,
#  'Yaris Hatchback': 8,
#  'Escape Hybrid AWD': 8,
#  'Nubira': 8,
#  '911 Targa 4 GTS': 8,
#  'K2500 4X4': 8,
#  'S60 R AWD Turbo': 8,
#  '718 Boxster': 8,
#  'Cooper Coupe': 8,
#  'Panamera GTS': 8,
#  'MDX AWD': 8,
#  'Vitara Convertible 4X4': 8,
#  'FR-S': 8,
#  'Cooper Roadster': 8,
#  'Cooper S Coupe': 8,
#  'Cooper S Roadster': 8,
#  'V70 T5 Turbo': 8,
#  'S60 2.5T AWD Turbo': 8,
#  'Impreza 2.5i': 8,
#  'Range Rover Evoque': 8,
#  'Aventador Roadster': 8,
#  'Jetta GLX': 8,
#  'XV Crosstrek AWD': 8,
#  'S60 2.5T Turbo': 8,
#  'GV80 AWD': 8,
#  'Carrera 2 Cabriolet': 8,
#  'Venue': 8,
#  'SLK 55 AMG': 8,
#  'GL 550 4MATIC': 8,
#  'Wave': 8,
#  'Cargo Van FFV': 8,
#  'Continental Flying Spur': 8,
#  'Ram 2500 4X4': 8,
#  'Challenger SRT Hellcat Widebody': 8,
#  'A7 quattro': 8,
#  '230i Coupe': 8,
#  'M6': 8,
#  'Dart Turbo Aero': 8,
#  '500X AWD': 8,
#  'Bronco Sport 4WD': 8,
#  'Dart FFV': 8,
#  'Caravan C/V': 8,
#  'Eldorado': 8,
#  'CLK 320': 8,
#  'F-150 FFV (Without Stop-Start)': 8,
#  '430i xDrive Coupe': 8,
#  '440i Coupe': 8,
#  '440i xDrive Coupe': 8,
#  'Elantra Touring': 8,
#  'Rendezvous': 8,
#  'Sonic RS': 8,
#  ...}

# %% [markdown]
# 🔷 The "Model" column should naturally be removed. Because the purpose of this model is to predict fuel consumption and CO2 emissions. These indicators are usually calculated, estimated and provided by the manufacturer for each vehicle based on its technical characteristics. As a result, predicting them is meaningless.

# %%
data.drop(columns=["Model"], inplace=True)

# %%
data
# Out:
#        Model year   Make                    Vehicle class  Engine size (L)  \
# 0            1995  Acura                       Subcompact              1.8
# 1            1995  Acura                       Subcompact              1.8
# 2            1995  Acura                       Subcompact              1.8
# 3            1995  Acura                          Compact              3.2
# 4            1995  Acura                          Compact              3.2
# ...           ...    ...                              ...              ...
# 27808        2024  Volvo             Station wagon: Small              2.0
# 27809        2024  Volvo          Station wagon: Mid-size              2.0
# 27810        2024  Volvo     Sport utility vehicle: Small              2.0
# 27811        2024  Volvo     Sport utility vehicle: Small              2.0
# 27812        2024  Volvo  Sport utility vehicle: Standard              2.0
#
#        Cylinders Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0              4           A4         X             11.6                 8.3
# 1              4           M5         X             11.0                 8.3
# 2              4           M5         Z             10.8                 8.3
# 3              6           A4         Z             14.2                10.5
# 4              6           A4         Z             14.6                11.0
# ...          ...          ...       ...              ...                 ...
# 27808          4          AS8         Z             10.0                 7.5
# 27809          4          AS8         Z             10.7                 8.1
# 27810          4          AS8         Z              9.9                 7.8
# 27811          4          AS8         Z             10.6                 8.3
# 27812          4          AS8         Z             10.9                 8.6
#
#        Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)
# 0                     10.1              28                   232
# 1                      9.8              29                   225
# 2                      9.7              29                   223
# 3                     12.5              23                   288
# 4                     13.0              22                   299
# ...                    ...             ...                   ...
# 27808                  8.9              32                   207
# 27809                  9.5              30                   223
# 27810                  9.0              31                   210
# 27811                  9.6              29                   226
# 27812                  9.8              29                   230
#
# [27813 rows x 12 columns]

# %%
data["Vehicle class"].value_counts().to_dict()
# Out:
# {'Compact': 3837,
#  'Mid-size': 3593,
#  'Sport utility vehicle': 3044,
#  'Pickup truck: Standard': 2961,
#  'Subcompact': 2658,
#  'Sport utility vehicle: Small': 2158,
#  'Full-size': 1761,
#  'Two-seater': 1510,
#  'Sport utility vehicle: Standard': 1430,
#  'Minicompact': 1136,
#  'Station wagon: Small': 991,
#  'Pickup truck: Small': 614,
#  'Minivan': 610,
#  'Station wagon: Mid-size': 524,
#  'Van: Cargo': 469,
#  'Van: Passenger': 398,
#  'Special purpose vehicle': 119}

# %%
sorted(data["Vehicle class"].value_counts().to_dict())
# Out:
# ['Compact',
#  'Full-size',
#  'Mid-size',
#  'Minicompact',
#  'Minivan',
#  'Pickup truck: Small',
#  'Pickup truck: Standard',
#  'Special purpose vehicle',
#  'Sport utility vehicle',
#  'Sport utility vehicle: Small',
#  'Sport utility vehicle: Standard',
#  'Station wagon: Mid-size',
#  'Station wagon: Small',
#  'Subcompact',
#  'Two-seater',
#  'Van: Cargo',
#  'Van: Passenger']

# %% [markdown]
# 🔷 For simplifying the model, we change the values of "Vehicle class" in this way:

# %%
data.loc[data["Vehicle class"].isin(["Pickup truck: Small","Pickup truck: Standard"]), "Vehicle class" ] = "Pickup truck"

data.loc[data["Vehicle class"].isin(["Sport utility vehicle: Small","Sport utility vehicle: Standard"]), "Vehicle class" ] = "Sport utility vehicle"

data.loc[data["Vehicle class"].isin(["Station wagon: Mid-size","Station wagon: Small"]), "Vehicle class" ] = "Station wagon"

data.loc[data["Vehicle class"].isin(["Van: Cargo","Van: Passenger"]), "Vehicle class" ] = "Van"

# %%
data
# Out:
#        Model year   Make          Vehicle class  Engine size (L)  Cylinders  \
# 0            1995  Acura             Subcompact              1.8          4
# 1            1995  Acura             Subcompact              1.8          4
# 2            1995  Acura             Subcompact              1.8          4
# 3            1995  Acura                Compact              3.2          6
# 4            1995  Acura                Compact              3.2          6
# ...           ...    ...                    ...              ...        ...
# 27808        2024  Volvo          Station wagon              2.0          4
# 27809        2024  Volvo          Station wagon              2.0          4
# 27810        2024  Volvo  Sport utility vehicle              2.0          4
# 27811        2024  Volvo  Sport utility vehicle              2.0          4
# 27812        2024  Volvo  Sport utility vehicle              2.0          4
#
#       Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0               A4         X             11.6                 8.3
# 1               M5         X             11.0                 8.3
# 2               M5         Z             10.8                 8.3
# 3               A4         Z             14.2                10.5
# 4               A4         Z             14.6                11.0
# ...            ...       ...              ...                 ...
# 27808          AS8         Z             10.0                 7.5
# 27809          AS8         Z             10.7                 8.1
# 27810          AS8         Z              9.9                 7.8
# 27811          AS8         Z             10.6                 8.3
# 27812          AS8         Z             10.9                 8.6
#
#        Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)
# 0                     10.1              28                   232
# 1                      9.8              29                   225
# 2                      9.7              29                   223
# 3                     12.5              23                   288
# 4                     13.0              22                   299
# ...                    ...             ...                   ...
# 27808                  8.9              32                   207
# 27809                  9.5              30                   223
# 27810                  9.0              31                   210
# 27811                  9.6              29                   226
# 27812                  9.8              29                   230
#
# [27813 rows x 12 columns]

# %%
data["Vehicle class"].value_counts().to_dict()
# Out:
# {'Sport utility vehicle': 6632,
#  'Compact': 3837,
#  'Mid-size': 3593,
#  'Pickup truck': 3575,
#  'Subcompact': 2658,
#  'Full-size': 1761,
#  'Station wagon': 1515,
#  'Two-seater': 1510,
#  'Minicompact': 1136,
#  'Van': 867,
#  'Minivan': 610,
#  'Special purpose vehicle': 119}

# %%
sorted(data["Vehicle class"].value_counts().to_dict())
# Out:
# ['Compact',
#  'Full-size',
#  'Mid-size',
#  'Minicompact',
#  'Minivan',
#  'Pickup truck',
#  'Special purpose vehicle',
#  'Sport utility vehicle',
#  'Station wagon',
#  'Subcompact',
#  'Two-seater',
#  'Van']

# %% [markdown]
# Sedans: Minicompact, Subcompact, Compact, Mid-size, Full-size

# %% [markdown]
# Station Wagons: Station wagon

# %% [markdown]
# Trucks: Pickup truck, Van, Minivan, Sport utility vehicle, Special purpose vehicle

# %% [markdown]
# Two Seaters: Two-seater

# %%
data[["Engine size (L)"]].describe()
# Out:
#        Engine size (L)
# count     27813.000000
# mean          3.340237
# std           1.341174
# min           0.800000
# 25%           2.200000
# 50%           3.000000
# 75%           4.200000
# max           8.400000

# %% [markdown]
# 🔷 The column "Engine size" has no problem...

# %%
data["Cylinders"].value_counts().to_dict()
# Out:
# {4: 10051, 6: 9907, 8: 6308, 5: 591, 12: 523, 3: 216, 10: 184, 2: 17, 16: 16}

# %%
data[["Cylinders"]].describe()
# Out:
#           Cylinders
# count  27813.000000
# mean       5.828893
# std        1.806877
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max       16.000000

# %% [markdown]
# 🔷 The column "Cylinders" has no problem...

# %%
data["Transmission"].value_counts().to_dict()
# Out:
# {'A4': 5489,
#  'M5': 3222,
#  'AS6': 2911,
#  'M6': 2799,
#  'AS8': 2193,
#  'A6': 1975,
#  'A5': 1604,
#  'A8': 989,
#  'AV': 895,
#  'AS5': 874,
#  'AM7': 794,
#  'A9': 650,
#  'AS7': 621,
#  'AS10': 506,
#  'A7': 281,
#  'A10': 279,
#  'AS4': 258,
#  'AM6': 232,
#  'AM8': 232,
#  'A3': 187,
#  'AV6': 159,
#  'AS9': 158,
#  'AV7': 157,
#  'M7': 151,
#  'AV8': 124,
#  'AV10': 39,
#  'AV1': 19,
#  'AM9': 6,
#  'AM5': 6,
#  'M4': 3}

# %% [markdown]
# 🔷 In 895 samples, "AV" is setted for "Transmission" column. should be removed.

# %%
data.drop(index=list(data.loc[data["Transmission"] == "AV"].index), inplace=True)
data.reset_index(inplace=True)
data.drop(columns=["index"], inplace=True)

# %%
data
# Out:
#        Model year   Make          Vehicle class  Engine size (L)  Cylinders  \
# 0            1995  Acura             Subcompact              1.8          4
# 1            1995  Acura             Subcompact              1.8          4
# 2            1995  Acura             Subcompact              1.8          4
# 3            1995  Acura                Compact              3.2          6
# 4            1995  Acura                Compact              3.2          6
# ...           ...    ...                    ...              ...        ...
# 26913        2024  Volvo          Station wagon              2.0          4
# 26914        2024  Volvo          Station wagon              2.0          4
# 26915        2024  Volvo  Sport utility vehicle              2.0          4
# 26916        2024  Volvo  Sport utility vehicle              2.0          4
# 26917        2024  Volvo  Sport utility vehicle              2.0          4
#
#       Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0               A4         X             11.6                 8.3
# 1               M5         X             11.0                 8.3
# 2               M5         Z             10.8                 8.3
# 3               A4         Z             14.2                10.5
# 4               A4         Z             14.6                11.0
# ...            ...       ...              ...                 ...
# 26913          AS8         Z             10.0                 7.5
# 26914          AS8         Z             10.7                 8.1
# 26915          AS8         Z              9.9                 7.8
# 26916          AS8         Z             10.6                 8.3
# 26917          AS8         Z             10.9                 8.6
#
#        Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)
# 0                     10.1              28                   232
# 1                      9.8              29                   225
# 2                      9.7              29                   223
# 3                     12.5              23                   288
# 4                     13.0              22                   299
# ...                    ...             ...                   ...
# 26913                  8.9              32                   207
# 26914                  9.5              30                   223
# 26915                  9.0              31                   210
# 26916                  9.6              29                   226
# 26917                  9.8              29                   230
#
# [26918 rows x 12 columns]

# %% [markdown]
# 🔷 Separating transmission type and number of gears.

# %%
Number_Of_Gears = []
NOG = ""

for index,value in zip(list(data["Transmission"].keys()), list(data["Transmission"].values)):
    
    for i in value:
        if i.isnumeric() == True:
            NOG = NOG + i
            
    Number_Of_Gears.append(int(NOG))
    data.loc[index, "Transmission"] = value[:-len(NOG)]
    NOG = ""
    
data.insert(6, "Number of gears", Number_Of_Gears)

# %%
data
# Out:
#        Model year   Make          Vehicle class  Engine size (L)  Cylinders  \
# 0            1995  Acura             Subcompact              1.8          4
# 1            1995  Acura             Subcompact              1.8          4
# 2            1995  Acura             Subcompact              1.8          4
# 3            1995  Acura                Compact              3.2          6
# 4            1995  Acura                Compact              3.2          6
# ...           ...    ...                    ...              ...        ...
# 26913        2024  Volvo          Station wagon              2.0          4
# 26914        2024  Volvo          Station wagon              2.0          4
# 26915        2024  Volvo  Sport utility vehicle              2.0          4
# 26916        2024  Volvo  Sport utility vehicle              2.0          4
# 26917        2024  Volvo  Sport utility vehicle              2.0          4
#
#       Transmission  Number of gears Fuel type  City (L/100 km)  \
# 0                A                4         X             11.6
# 1                M                5         X             11.0
# 2                M                5         Z             10.8
# 3                A                4         Z             14.2
# 4                A                4         Z             14.6
# ...            ...              ...       ...              ...
# 26913           AS                8         Z             10.0
# 26914           AS                8         Z             10.7
# 26915           AS                8         Z              9.9
# 26916           AS                8         Z             10.6
# 26917           AS                8         Z             10.9
#
#        Highway (L/100 km)  Combined (L/100 km)  Combined (mpg)  \
# 0                     8.3                 10.1              28
# 1                     8.3                  9.8              29
# 2                     8.3                  9.7              29
# 3                    10.5                 12.5              23
# 4                    11.0                 13.0              22
# ...                   ...                  ...             ...
# 26913                 7.5                  8.9              32
# 26914                 8.1                  9.5              30
# 26915                 7.8                  9.0              31
# 26916                 8.3                  9.6              29
# 26917                 8.6                  9.8              29
#
#        CO2 emissions (g/km)
# 0                       232
# 1                       225
# 2                       223
# 3                       288
# 4                       299
# ...                     ...
# 26913                   207
# 26914                   223
# 26915                   210
# 26916                   226
# 26917                   230
#
# [26918 rows x 13 columns]

# %%
data["Fuel type"].value_counts()
# Out:
# Fuel type
# X    14381
# Z    10905
# E     1098
# D      495
# N       39
# Name: count, dtype: int64

# %% [markdown]
# 🔷 According to the dataset description, we change the "fuel type" column.

# %%
data.loc[data["Fuel type"] == "X", "Fuel type"] = "Regular gasoline"

data.loc[data["Fuel type"] == "Z", "Fuel type"] = "Premium gasoline"

data.loc[data["Fuel type"] == "D", "Fuel type"] = "Diesel"

data.loc[data["Fuel type"] == "E", "Fuel type"] = "Ethanol (E85)"

data.loc[data["Fuel type"] == "N", "Fuel type"] = "Natural Gas"

# %%
data
# Out:
#        Model year   Make          Vehicle class  Engine size (L)  Cylinders  \
# 0            1995  Acura             Subcompact              1.8          4
# 1            1995  Acura             Subcompact              1.8          4
# 2            1995  Acura             Subcompact              1.8          4
# 3            1995  Acura                Compact              3.2          6
# 4            1995  Acura                Compact              3.2          6
# ...           ...    ...                    ...              ...        ...
# 26913        2024  Volvo          Station wagon              2.0          4
# 26914        2024  Volvo          Station wagon              2.0          4
# 26915        2024  Volvo  Sport utility vehicle              2.0          4
# 26916        2024  Volvo  Sport utility vehicle              2.0          4
# 26917        2024  Volvo  Sport utility vehicle              2.0          4
#
#       Transmission  Number of gears         Fuel type  City (L/100 km)  \
# 0                A                4  Regular gasoline             11.6
# 1                M                5  Regular gasoline             11.0
# 2                M                5  Premium gasoline             10.8
# 3                A                4  Premium gasoline             14.2
# 4                A                4  Premium gasoline             14.6
# ...            ...              ...               ...              ...
# 26913           AS                8  Premium gasoline             10.0
# 26914           AS                8  Premium gasoline             10.7
# 26915           AS                8  Premium gasoline              9.9
# 26916           AS                8  Premium gasoline             10.6
# 26917           AS                8  Premium gasoline             10.9
#
#        Highway (L/100 km)  Combined (L/100 km)  Combined (mpg)  \
# 0                     8.3                 10.1              28
# 1                     8.3                  9.8              29
# 2                     8.3                  9.7              29
# 3                    10.5                 12.5              23
# 4                    11.0                 13.0              22
# ...                   ...                  ...             ...
# 26913                 7.5                  8.9              32
# 26914                 8.1                  9.5              30
# 26915                 7.8                  9.0              31
# 26916                 8.3                  9.6              29
# 26917                 8.6                  9.8              29
#
#        CO2 emissions (g/km)
# 0                       232
# 1                       225
# 2                       223
# 3                       288
# 4                       299
# ...                     ...
# 26913                   207
# 26914                   223
# 26915                   210
# 26916                   226
# 26917                   230
#
# [26918 rows x 13 columns]

# %%
data["City (L/100 km)"].describe()
# Out:
# count    26918.000000
# mean        13.967973
# std          3.664321
# min          4.000000
# 25%         11.400000
# 50%         13.500000
# 75%         16.000000
# max         33.300000
# Name: City (L/100 km), dtype: float64

# %% [markdown]
# 🔷 The column "City (L/100 km)" has no problem...

# %%
data["Highway (L/100 km)"].describe()
# Out:
# count    26918.000000
# mean        10.079178
# std          2.567706
# min          3.900000
# 25%          8.300000
# 50%          9.600000
# 75%         11.400000
# max         22.100000
# Name: Highway (L/100 km), dtype: float64

# %% [markdown]
# 🔷 The column "Highway (L/100 km)" has no problem...

# %%
data["Combined (L/100 km)"].describe()
# Out:
# count    26918.000000
# mean        12.218062
# std          3.133751
# min          4.000000
# 25%         10.000000
# 50%         11.700000
# 75%         13.900000
# max         27.500000
# Name: Combined (L/100 km), dtype: float64

# %% [markdown]
# 🔷 The column "Combined (L/100 km)" has no problem...

# %% [markdown]
# 🔷 The column "Combined (mpg)" is no needed. should be removed.

# %%
data.drop(columns=["Combined (mpg)"], inplace=True)

# %%
data
# Out:
#        Model year   Make          Vehicle class  Engine size (L)  Cylinders  \
# 0            1995  Acura             Subcompact              1.8          4
# 1            1995  Acura             Subcompact              1.8          4
# 2            1995  Acura             Subcompact              1.8          4
# 3            1995  Acura                Compact              3.2          6
# 4            1995  Acura                Compact              3.2          6
# ...           ...    ...                    ...              ...        ...
# 26913        2024  Volvo          Station wagon              2.0          4
# 26914        2024  Volvo          Station wagon              2.0          4
# 26915        2024  Volvo  Sport utility vehicle              2.0          4
# 26916        2024  Volvo  Sport utility vehicle              2.0          4
# 26917        2024  Volvo  Sport utility vehicle              2.0          4
#
#       Transmission  Number of gears         Fuel type  City (L/100 km)  \
# 0                A                4  Regular gasoline             11.6
# 1                M                5  Regular gasoline             11.0
# 2                M                5  Premium gasoline             10.8
# 3                A                4  Premium gasoline             14.2
# 4                A                4  Premium gasoline             14.6
# ...            ...              ...               ...              ...
# 26913           AS                8  Premium gasoline             10.0
# 26914           AS                8  Premium gasoline             10.7
# 26915           AS                8  Premium gasoline              9.9
# 26916           AS                8  Premium gasoline             10.6
# 26917           AS                8  Premium gasoline             10.9
#
#        Highway (L/100 km)  Combined (L/100 km)  CO2 emissions (g/km)
# 0                     8.3                 10.1                   232
# 1                     8.3                  9.8                   225
# 2                     8.3                  9.7                   223
# 3                    10.5                 12.5                   288
# 4                    11.0                 13.0                   299
# ...                   ...                  ...                   ...
# 26913                 7.5                  8.9                   207
# 26914                 8.1                  9.5                   223
# 26915                 7.8                  9.0                   210
# 26916                 8.3                  9.6                   226
# 26917                 8.6                  9.8                   230
#
# [26918 rows x 12 columns]

# %%
data["CO2 emissions (g/km)"].describe()
# Out:
# count    26918.000000
# mean       277.903819
# std         64.611739
# min         94.000000
# 25%        232.000000
# 50%        270.000000
# 75%        317.000000
# max        633.000000
# Name: CO2 emissions (g/km), dtype: float64

# %% [markdown]
# 🔷 The column "CO2 emissions (g/km)" has no problem...

# %% [markdown]
# ### 🟦 Saving Data

# %%
data.to_csv(path_or_buf=os.path.basename("\Data\data-cleaned.csv"), sep=",", index=False, encoding="utf-8")
